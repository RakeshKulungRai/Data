# %%
import numpy as np
import matplotlib.pyplot as plt
mu,sigma = 172, 8

# %%
x = mu + sigma * np.random.randn(1000) #nfor normal distribution
plt.hist(x,100,facecolor='blue')
plt.show()

# %%
# x = mu + sigma * np.random.randn(10000) #nfor normal distribution
# plt.hist(x,100,facecolor='blue',density = True)
# plt.xlabel('Height')
# plt.ylabel('Percentage')
# plt.title('Student Height')
# plt.text(145,15,'mu =172 sigma =8')
# plt.grid(True)
# plt.show()

# %%
x = np.random.rand(50)
y = np.random.rand(50)
plt.scatter(x,y)
plt.show()

# %%
x = [10, 20, 30, 40,20]
y =[5,7,8,9,4]
plt.scatter(x,y)
plt.show()

# %%
x = [10, 20, 30, 40,20]
y =[5,7,8,9,4]
plt.scatter(x,y,c='r', marker ='x',s=224) #s is size of scatter plot
plt.show()
