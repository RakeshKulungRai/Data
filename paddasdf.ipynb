# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data  ={
    'SSN' : [1,2,3,4,5],
    'Name' :['rakesh','rai','anna','jhon','nuna'],
    'Age' : [29, 45,33, 187,123],
    'Height' : [135,345,124,345,784],
    'Gender' :['m','m','f','m','f'],
    'random' :[4,5,6,7,8]
    
}
df = pd.DataFrame(data)

# %%
print(df)
# Out:
#    SSN    Name  Age  Height Gender  random
# 0    1  rakesh   29     135      m       4
# 1    2     rai   45     345      m       5
# 2    3    anna   33     124      f       6
# 3    4    jhon  187     345      m       7
# 4    5    nuna  123     784      f       8

# %%
df.set_index('SSN',inplace=True)

# %%
print(df.head(2))
print(df.tail(2))
# Out:
#        Name  Age  Height Gender  random
# SSN
# 1    rakesh   29     135      m       4
# 2       rai   45     345      m       5
#      Name  Age  Height Gender  random
# SSN
# 4    jhon  187     345      m       7
# 5    nuna  123     784      f       8

# %%
print(df.ndim) #2dimension due to cols and rows
# Out:
# 2

# %%
print(df.shape)
# Out:
# (5, 5)

# %%
print(df.dtypes)
# Out:
# Name      object
# Age        int64
# Height     int64
# Gender    object
# random     int64
# dtype: object

# %%
print(df.T)
# Out:
# SSN          1    2     3     4     5
# Name    rakesh  rai  anna  jhon  nuna
# Age         29   45    33   187   123
# Height     135  345   124   345   784
# Gender       m    m     f     m     f
# random       4    5     6     7     8

# %%
print(df['Name'].iloc[1])
# Out:
# rai

# %%
print(df)
# Out:
#        Name  Age  Height Gender  random
# SSN
# 1    rakesh   29     135      m       4
# 2       rai   45     345      m       5
# 3      anna   33     124      f       6
# 4      jhon  187     345      m       7
# 5      nuna  123     784      f       8

# %%
print(df.iloc[0])
# Out:
# Name      rakesh
# Age           29
# Height       135
# Gender         m
# random         4
# Name: 1, dtype: object

# %%
print(df.iloc[0]['Age'])
# Out:
# 29

# %%
df['Age'].plot()
plt.show()

# %%
df.plot()
plt.show()

# %%
df['Height'].plot.hist()
plt.show()

# %%
df.hist()
plt.show()

# %%
df['Height'].plot.pie(labels=df['Name'])
# Out:
# <AxesSubplot: ylabel='Height'>

# %%
df.plot.bar()
# Out:
# <AxesSubplot: xlabel='SSN'>

# %%
df.ag
